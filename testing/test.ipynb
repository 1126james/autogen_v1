# %%
import pandas as pd
import numpy as np
from pathlib import Path
from typing import Dict, Any, Union

def LoadDataset(file_path: Union[str, Path]) -> pd.DataFrame:
    """
    Load various tabular data formats into a pandas DataFrame.
    Supports CSV, Excel, and other common formats.
    """
    file_path = Path(file_path)
    if file_path.suffix.lower() == '.csv':
        return pd.read_csv(file_path)
    elif file_path.suffix.lower() in ['.xlsx', '.xls']:
        return pd.read_excel(file_path)
    else:
        raise ValueError(f"Unsupported file format: {file_path.suffix}")

def GetDatasetProfile(df: pd.DataFrame) -> Dict[str, Dict[str, Any]]:
    """
    Create a comprehensive profile of the dataset including statistics and metadata.
    """
    profile = {}
    
    for col in df.columns:
        col_stats = {
            'dtype': str(df[col].dtype),
            'total_count': len(df[col]),
            'null_count': df[col].isna().sum(),
            'null_percentage': (df[col].isna().sum() / len(df[col])) * 100,
            'unique_count': df[col].nunique()
        }
        
        # Add numerical statistics if applicable
        if pd.api.types.is_numeric_dtype(df[col]):
            col_stats.update({
                'mean': df[col].mean() if not df[col].empty else None,
                'median': df[col].median() if not df[col].empty else None,
                'std': df[col].std() if not df[col].empty else None,
                'min': df[col].min() if not df[col].empty else None,
                'max': df[col].max() if not df[col].empty else None
            })
        
        # Check for various null representations
        null_variants = ['NA', 'Na', 'na', 'NULL', 'Null', 'null', 'NAN', 'Nan', 'nan']
        if df[col].dtype == 'object':
            null_like_count = df[col].isin(null_variants).sum()
            col_stats['alternative_null_count'] = null_like_count
        
        profile[col] = col_stats
    
    return profile

# %%
df = LoadDataset('../sheets/credit_card_transactions.csv')
GetDatasetProfile(df)
# Out:
# {'Unnamed: 0': {'dtype': 'int64',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 1296675,
#   'mean': 648337.0,
#   'median': 648337.0,
#   'std': 374317.9744882685,
#   'min': 0,
#   'max': 1296674},
#  'trans_date_trans_time': {'dtype': 'object',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 1274791,
#   'alternative_null_count': 0},
#  'cc_num': {'dtype': 'int64',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 983,
#   'mean': 4.1719204207972666e+17,
#   'median': 3521417320836166.0,
#   'std': 1.3088064470002404e+18,
#   'min': 60416207185,
#   'max': 4992346398065154184},
#  'merchant': {'dtype': 'object',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 693,
#   'alternative_null_count': 0},
#  'category': {'dtype': 'object',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 14,
#   'alternative_null_count': 0},
#  'amt': {'dtype': 'float64',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 52928,
#   'mean': 70.35103545607033,
#   'median': 47.52,
#   'std': 160.31603857152774,
#   'min': 1.0,
#   'max': 28948.9},
#  'first': {'dtype': 'object',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 352,
#   'alternative_null_count': 0},
#  'last': {'dtype': 'object',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 481,
#   'alternative_null_count': 0},
#  'gender': {'dtype': 'object',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 2,
#   'alternative_null_count': 0},
#  'street': {'dtype': 'object',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 983,
#   'alternative_null_count': 0},
#  'city': {'dtype': 'object',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 894,
#   'alternative_null_count': 0},
#  'state': {'dtype': 'object',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 51,
#   'alternative_null_count': 0},
#  'zip': {'dtype': 'int64',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 970,
#   'mean': 48800.67109722945,
#   'median': 48174.0,
#   'std': 26893.2224764859,
#   'min': 1257,
#   'max': 99783},
#  'lat': {'dtype': 'float64',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 968,
#   'mean': 38.53762161489965,
#   'median': 39.3543,
#   'std': 5.075808438803932,
#   'min': 20.0271,
#   'max': 66.6933},
#  'long': {'dtype': 'float64',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 969,
#   'mean': -90.22633537864147,
#   'median': -87.4769,
#   'std': 13.759076946486312,
#   'min': -165.6723,
#   'max': -67.9503},
#  'city_pop': {'dtype': 'int64',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 879,
#   'mean': 88824.44056297839,
#   'median': 2456.0,
#   'std': 301956.360688751,
#   'min': 23,
#   'max': 2906700},
#  'job': {'dtype': 'object',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 494,
#   'alternative_null_count': 0},
#  'dob': {'dtype': 'object',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 968,
#   'alternative_null_count': 0},
#  'trans_num': {'dtype': 'object',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 1296675,
#   'alternative_null_count': 0},
#  'unix_time': {'dtype': 'int64',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 1274823,
#   'mean': 1349243636.7261226,
#   'median': 1349249747.0,
#   'std': 12841278.423359346,
#   'min': 1325376018,
#   'max': 1371816817},
#  'merch_lat': {'dtype': 'float64',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 1247805,
#   'mean': 38.53733804469971,
#   'median': 39.36568,
#   'std': 5.109788369679177,
#   'min': 19.027785,
#   'max': 67.510267},
#  'merch_long': {'dtype': 'float64',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 1275745,
#   'mean': -90.22646479897277,
#   'median': -87.43839200000001,
#   'std': 13.77109056479242,
#   'min': -166.671242,
#   'max': -66.950902},
#  'is_fraud': {'dtype': 'int64',
#   'total_count': 1296675,
#   'null_count': 0,
#   'null_percentage': 0.0,
#   'unique_count': 2,
#   'mean': 0.005788651743883394,
#   'median': 0.0,
#   'std': 0.07586268973125164,
#   'min': 0,
#   'max': 1},
#  'merch_zipcode': {'dtype': 'float64',
#   'total_count': 1296675,
#   'null_count': 195973,
#   'null_percentage': 15.113501841247807,
#   'unique_count': 28336,
#   'mean': 46825.75415053302,
#   'median': 45860.0,
#   'std': 25834.00115959987,
#   'min': 1001.0,
#   'max': 99403.0}}
