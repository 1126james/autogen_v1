# %%
# Out:
# This dataset contains 25 columns:
#
# • Unnamed: 0.1:
#   - Type: int64
#   - Sample value: 1045211
#   - Contains 10 entries with 0 nulls (0.0%)
#   - Has 10 unique values
#   - Numerical stats: mean=683875.70, median=755029.00
#   - Range: 110142.00 to 1285953.00
#
# • Unnamed: 0:
#   - Type: int64
#   - Sample value: 1045211
#   - Contains 10 entries with 0 nulls (0.0%)
#   - Has 10 unique values
#   - Numerical stats: mean=683875.70, median=755029.00
#   - Range: 110142.00 to 1285953.00
#
# • trans_date_trans_time:
#   - Type: object
#   - Sample value: 2020-03-09 15:09:26
#   - Contains 10 entries with 0 nulls (0.0%)
#   - Has 10 unique values
#
# • cc_num:
#   - Type: int64
#   - Sample value: 577588686219
#   - Contains 10 entries with 0 nulls (0.0%)
#   - Has 10 unique values
#   - Numerical stats: mean=487655012726842880.00, median=1864008873318950.50
#   - Range: 577588686219.00 to 4855488158131690496.00
#
# • merchant:
#   - Type: object
# ...
